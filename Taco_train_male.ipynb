# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhav2711/Tacotron/blob/main/Taco_train_male.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget http://www.caito.de/data/Training/stt_tts/en_US.tgz
# Out:
# --2021-01-23 15:57:23--  http://www.caito.de/data/Training/stt_tts/en_US.tgz
# Resolving www.caito.de (www.caito.de)... 176.28.12.219
# Connecting to www.caito.de (www.caito.de)|176.28.12.219|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.caito.de/data/Training/stt_tts/en_US.tgz [following]
# --2021-01-23 15:57:24--  https://www.caito.de/data/Training/stt_tts/en_US.tgz
# Connecting to www.caito.de (www.caito.de)|176.28.12.219|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8016794960 (7.5G) [application/x-gzip]
# Saving to: ‘en_US.tgz’
#
# en_US.tgz           100%[===================>]   7.47G  11.8MB/s    in 10m 47s
#
# 2021-01-23 16:08:11 (11.8 MB/s) - ‘en_US.tgz’ saved [8016794960/8016794960]

# %%
# !tar -xvf  'en_US.tgz'
# Out:
# Streaming output truncated to the last 5000 lines.
# en_US/by_book/female/mary_ann/northandsouth/wavs/northandsouth_38_f000252.wav
# en_US/by_book/female/mary_ann/northandsouth/wavs/northandsouth_30_f000050.wav
# en_US/by_book/female/mary_ann/northandsouth/wavs/northandsouth_37_f000163.wav
# en_US/by_book/female/mary_ann/northandsouth/wavs/northandsouth_50_f000080.wav
# en_US/by_book/female/mary_ann/northandsouth/wavs/northandsouth_28_f000088.wav
# en_US/by_book/female/mary_ann/northandsouth/wavs/northandsouth_23_f000138.wav
# en_US/by_book/female/mary_ann/northandsouth/wavs/northandsouth_12_f000097.wav
# en_US/by_book/female/mary_ann/northandsouth/wavs/northandsouth_28_f000089.wav
# en_US/by_book/female/mary_ann/northandsouth/wavs/northandsouth_27_f000047.wav
# en_US/by_book/female/mary_ann/northandsouth/wavs/northandsouth_46_f000247.wav
# en_US/by_book/female/mary_ann/northandsouth/wavs/northandsouth_42_f000218.wav
# ...

# %%
# !rm -r /content/en_US/by_book/female

# %%
import os

# %%
# %cd /content
# Out:
# /content

# %%
 # !git clone https://github.com/mozilla/TTS
# Out:
# Cloning into 'TTS'...
# remote: Enumerating objects: 187, done.
# remote: Counting objects: 100% (187/187), done.
# remote: Compressing objects: 100% (103/103), done.
# remote: Total 11121 (delta 97), reused 125 (delta 79), pack-reused 10934
# Receiving objects: 100% (11121/11121), 122.83 MiB | 32.64 MiB/s, done.
# Resolving deltas: 100% (7750/7750), done.

# %%
# !sudo apt-get install espeak
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   espeak-data libespeak1 libportaudio2 libsonic0
# The following NEW packages will be installed:
#   espeak espeak-data libespeak1 libportaudio2 libsonic0
# 0 upgraded, 5 newly installed, 0 to remove and 13 not upgraded.
# Need to get 1,219 kB of archives.
# After this operation, 3,031 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libportaudio2 amd64 19.6.0-1 [64.6 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsonic0 amd64 0.2.0-6 [13.4 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 espeak-data amd64 1.48.04+dfsg-5 [934 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libespeak1 amd64 1.48.04+dfsg-5 [145 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 espeak amd64 1.48.04+dfsg-5 [61.6 kB]
# ...

# %%
# !pip install soundfile

# %%
# %cd TTS
# !git checkout b1935c97
#!python setup.py install
# %cd ..
# Out:
# /content/TTS
# Note: checking out 'b1935c97'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at b1935c9 update server to enable native vocoder inference and remove pwgan support
# /content

# %%
# !gdown --id 1dntzjWFg7ufWaTaFy80nRz-Tu02xWZos -O tts_model.pth.tar
# !gdown --id 18CQ6G6tBEOfvCHlPqP8EBI4xWbrr9dBc -O config.json
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1dntzjWFg7ufWaTaFy80nRz-Tu02xWZos
# To: /content/tts_model.pth.tar
# 347MB [00:03, 102MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=18CQ6G6tBEOfvCHlPqP8EBI4xWbrr9dBc
# To: /content/config.json
# 100% 9.53k/9.53k [00:00<00:00, 26.0MB/s]

# %%
#!gdown --id 1Ty5DZdOc0F7OTGj9oJThYbL5iVu_2G0K -O vocoder_model.pth.tar
#!gdown --id 1Rd0R_nRCrbjEdpOwq6XwZAktvugiBvmu -O config_vocoder.json
# !gdown --id 11oY3Tv0kQtxK_JPgxrfesa99maVXHNxU -O scale_stats.npy
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11oY3Tv0kQtxK_JPgxrfesa99maVXHNxU
# To: /content/scale_stats.npy
# 100% 10.5k/10.5k [00:00<00:00, 15.6MB/s]

# %%
pip install torch==1.6.0+cu101 torchvision==0.6.0+cu101 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 708.0MB 24kB/s
# ...
#      |████████████████████████████████| 6.6MB 26.7MB/s
# ...
# ERROR: torchvision 0.6.0+cu101 has requirement torch==1.5.0, but you'll have torch 1.6.0+cu101 which is incompatible.
# ...
#   Found existing installation: torch 1.7.0+cu101
#     Uninstalling torch-1.7.0+cu101:
#       Successfully uninstalled torch-1.7.0+cu101
#   Found existing installation: torchvision 0.8.1+cu101
#     Uninstalling torchvision-0.8.1+cu101:
#       Successfully uninstalled torchvision-0.8.1+cu101
# ...

# %%
import TTS

# %%
# !python TTS/compute_statistics.py --config_path config.json --out_path ./
# Out:
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > num_mels:80
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > stats_path:None
#  | > hop_length:256
#  | > win_length:1024
#  | > hunters_space/metadata.csv
#  | > pink_fairy_book/metadata.csv
#  | > pirates_of_ersatz/metadata.csv
#  | > poisoned_pen/metadata.csv
#  | > silent_bullet/metadata.csv
#  > There are 17034 files.
# 100% 17034/17034 [11:49<00:00, 24.02it/s]
#  > Avg mel spec mean: -2.5009840314460097
#  > Avg mel spec scale: 0.9311335991608496
#  > Avg linear spec mean: -1.7807880447170485
# ...

# %%
# !pip install phonemizer
# Out:
# ...
#      |████████████████████████████████| 51kB 4.3MB/s
# ...
#      |████████████████████████████████| 194kB 10.4MB/s
# ...
#      |████████████████████████████████| 51kB 4.4MB/s
# ...

# %%
# !pip install unidecode
# Out:
# ...
#      |████████████████████████████████| 245kB 10.5MB/s
# ...

# %%
# !pip install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 317kB 8.7MB/s
# ...

# %%
# !gdown --id 14cyzoi-SXCbGlrJBA0jlXnugJfAtP7Um
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=14cyzoi-SXCbGlrJBA0jlXnugJfAtP7Um
# To: /content/best_model.pth_2.tar
# 146MB [00:01, 116MB/s]

# %%
# !CUDA_VISIBLE_DEVICES="0" python TTS/train.py --config_path config.json
# Out:
# 2021-01-23 16:58:00.867877: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
#  > Using CUDA:  True
#  > Number of GPUs:  1
# fatal: not a git repository (or any of the parent directories): .git
#  > Git Hash: 0000000
#  > Experiment folder: /content/drive/MyDrive/TTS_Single_Speaker_OUT/ljspeech-tac2-January-23-2021_04+58PM-0000000
# fatal: not a git repository (or any of the parent directories): .git
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > num_mels:80
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:True
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
# ...

# %%
l = os.path.join('/content/en_US/by_book/male/','metadata_train.csv')

# %%
l
# Out:
# '/content/en_US/by_book/male/metadata_train.csv'

# %%
ls
# Out:
# config.json          en_US/           TTS/
# config_vocoder.json  sample_data/     tts_model.pth.tar
# drive/               scale_stats.npy  vocoder_model.pth.tar

# %%
# !rm -r en_US
